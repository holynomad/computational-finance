# %%
# 4-(a) 
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

T=0.5      #0.5년후 BM 예측(모델링)
N=int(1e5) #10만 samples

np.random.seed(0)

W_T= np.random.randn(N)*np.sqrt(T) #T시점에서의 브라우니안모션(W) 도출
mean_W_T=np.mean(W_T)
std_W_T=np.std(W_T)

print("mean = ", mean_W_T)
print("std = ", std_W_T)

ci_95 = norm.ppf(0.975) #norm.cdf(0.025)와 같은 의미
ci_99 = norm.ppf(0.995) #norm.cdf(0.0025)와 같은 의미

print(ci_95)
print(ci_99)

print("95% ci = [", mean_W_T-ci_95*std_W_T/np.sqrt(N), 
      ", ", mean_W_T+ci_95*std_W_T/np.sqrt(N), "]") #좀 더 정확하게 쓰려면 자유도가 N-1이 되어야 하나, 근사에 의해 무시가능

print("99% ci = [", mean_W_T-ci_99*std_W_T/np.sqrt(N), 
      ", ", mean_W_T+ci_99*std_W_T/np.sqrt(N), "]") #좀 더 정확하게 쓰려면 자유도가 N-1이 되어야 하나, 근사에 의해 무시가능


plt.hist(W_T, 1000)
plt.show()
# Out:
# mean =  0.0011148956211957017
# std =  0.7052256564092161
# 1.959963984540054
# 2.5758293035489004
# 95% ci = [ -0.003256057963765855 ,  0.005485849206157259 ]
# 99% ci = [ -0.00462951112168545 ,  0.006859302364076854 ]

# %%
# 4-(b)
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

T=0.5      #0.5년후 BM 예측(모델링)
N=int(1e5) #10만 samples

np.random.seed(0)

W_T= np.random.randn(N)*np.sqrt(T) #T시점에서의 브라우니안모션(W) 도출
#W_1= np.random.randn(N)*np.sqrt(1) #<-- 이렇게 접근하면 안됨 !!

W_1= W_T + np.random.randn(N)*np.sqrt(1) #<--W_1과 W_T는 독립이 아님 !! Cov(W_1, W_T) = T

X_T = W_T - T*W_1
mean_X_T = np.mean(X_T)
std_X_T = np.std(X_T)

print("mean = ", mean_X_T)
print("std = ", std_X_T)

ci_95 = norm.ppf(0.975) #norm.cdf(0.025)와 같은 의미
ci_99 = norm.ppf(0.995) #norm.cdf(0.0025)와 같은 의미

print("95% ci = [", mean_X_T-ci_95*std_X_T/np.sqrt(N), 
      ", ", mean_X_T+ci_95*std_X_T/np.sqrt(N), "]") #좀 더 정확하게 쓰려면 자유도가 N-1이 되어야 하나, 근사에 의해 무시가능

print("99% ci = [", mean_X_T-ci_99*std_X_T/np.sqrt(N), 
      ", ", mean_X_T+ci_99*std_X_T/np.sqrt(N), "]") #좀 더 정확하게 쓰려면 자유도가 N-1이 되어야 하나, 근사에 의해 무시가능


plt.hist(X_T, 1000)
plt.show()
# Out:
# mean =  -0.001989172851050016
# std =  0.6110761831200245
# 95% ci = [ -0.005776592677624254 ,  0.0017982469755242216 ]
# 99% ci = [ -0.006966686239604144 ,  0.0029883405375041123 ]

# %%
# 26page ref.
#!pip install seaborn
import seaborn as sns

S_0 = 100
T = 1.0
r = 0.02
sig = 0.3
mu = 0.05

N = int(1e5)

np.random.seed(0)

W_T=np.random.randn(N)*np.sqrt(T)
S_T_actual = S_0 * np.exp( (mu-sig*sig/2)*T + sig*W_T)
S_T_RN = S_0 * np.exp ( (r-sig*sig/2)*T + sig*W_T)

print("mean_S_T_actual = ", np.mean(S_T_actual))
print("mean_S_T_RN = ", np.mean(S_T_RN))

sns.distplot(S_T_actual, color='red', label = "S_T_actual")
sns.distplot(S_T_RN, color='blue', label = "S_T_RN")

plt.legend()

#plt.hist([S_T_actual, S_T_RN], 1000)
plt.show()
# Out:
# mean_S_T_actual =  105.14879109043557
# mean_S_T_RN =  102.04117467173837
# /usr/local/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
